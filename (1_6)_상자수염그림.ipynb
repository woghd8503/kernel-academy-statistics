# %% [markdown]
# <a href="https://colab.research.google.com/github/woghd8503/kernel-academy-statistics/blob/main/(1_6)_%E1%84%89%E1%85%A1%E1%86%BC%E1%84%8C%E1%85%A1%E1%84%89%E1%85%AE%E1%84%8B%E1%85%A7%E1%86%B7%E1%84%80%E1%85%B3%E1%84%85%E1%85%B5%E1%86%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
import seaborn as sns

df = pd.read_csv('gapminder.tsv', sep='\t')

sns.boxplot(x='continent', y='lifeExp', data=df)
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>
